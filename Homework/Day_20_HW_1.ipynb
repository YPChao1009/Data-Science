# %% [markdown]
# # 作業目標
#
# 1. 繪製模型殘差 圖型
#
#    更改初始值設定
#
#
# 2. (1)使用 distplot()使用簡單的規則來正確猜測預設情況下正確的數位,但嘗試更多或更少的 bin 可能會顯示資料中的其他特徵: <br>
#    (2)有無kde對圖形分布的影響

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in d:\anaconda3\envs\pt\lib\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.21 in d:\anaconda3\envs\pt\lib\site-packages (from statsmodels) (1.1.5)
# Requirement already satisfied: scipy>=1.1 in d:\anaconda3\envs\pt\lib\site-packages (from statsmodels) (1.5.4)
# Requirement already satisfied: numpy>=1.15 in d:\anaconda3\envs\pt\lib\site-packages (from statsmodels) (1.19.2)
# Requirement already satisfied: patsy>=0.5 in d:\anaconda3\envs\pt\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\anaconda3\envs\pt\lib\site-packages (from pandas>=0.21->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in d:\anaconda3\envs\pt\lib\site-packages (from pandas>=0.21->statsmodels) (2021.3)
# Requirement already satisfied: six in d:\anaconda3\envs\pt\lib\site-packages (from patsy>=0.5->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# `sns.residplot()`

# %%
import numpy as np
import seaborn as sns

#設定圖形樣式 - whitegrid
# use sns.set
sns.set(style="whitegrid")

# 利用 NUMPY 去建立資料集
# np.random.RandomState 設定數學式
'''
x = rs.normal(2, 1, 75)
y = 2 + 1.5 * x + rs.normal(0, 2, 75)
'''
rs = np.random.RandomState(7)
x = rs.normal(2, 1, 75)
y = 2 + 1.5 * x + rs.normal(0, 2, 75)

# 畫圖
# sns.residplot

sns.residplot(x, y, lowess=True, color="g")
# Out:
# D:\Anaconda3\envs\PT\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:>

# %% [markdown]
# 繪製單變數分佈:
#
# 快速檢視海出生單變數分佈的最便捷方式是distplot() 函數。默認情況下,這將繪製直方圖並適合內核密度估計值(KDE)。
#
# `sns.distplot()`<br>
# bin: 指的是特徵值<br>
# kde: on/off<br>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
sns.set(color_codes=True)

# bin: 指的是特徵值, 
# kde: on/off
# sns.distplot();

sns.distplot(x, bins=15, kde=False, rug=True);
# Out:
# D:\Anaconda3\envs\PT\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda3\envs\PT\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(x, bins=15, kde=True, rug=True);
# Out:
# D:\Anaconda3\envs\PT\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda3\envs\PT\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
